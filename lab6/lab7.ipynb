# %%
using Pkg
using QuadGK
using Polynomials
using Plots

# %%
#zadanie 1a
function Legrendre(n)
    tab = Array{Function}(undef, n)
    tab[1] = x -> 1
    tab[2] = x -> x
    for i in 3:n
        k = i - 1
        tab[i] = x -> ((2*k+1)*x*tab[k](x) - k*tab[k-1](x))/(k+1) 
    end
    return tab
end

n = 6
fs = Legrendre(n)

xs = -1:0.01:1
plot(xs, [fs[1](x) for x in xs], label = "P0")
plot!(xs, [fs[2](x) for x in xs], label = "P1")
plot!(xs, [fs[3](x) for x in xs], label = "P2")
plot!(xs, [fs[4](x) for x in xs], label = "P3")
plot!(xs, [fs[5](x) for x in xs], label = "P4")
plot!(xs, [fs[6](x) for x in xs], label = "P5")

# %%
#zadanie 1b
#2:
(xp, a) = gauss(Float64, 2)
println(xp)
println(Polynomials.roots((x -> x)[-1,0,1]))
println(" ")
#3:
#(xp, a) = gauss(Float64, 3)
#4:
#(xp, a) = gauss(Float64, 4)
# Out:
# [-0.5773502691896258, 0.5773502691896258]
# MethodError: no method matching roots(::var"#401#402")
# Closest candidates are:
#   roots(::P; kwargs...) where {T, X, P<:LaurentPolynomial{T, X}} at C:\Users\Szymon\.julia\packages\Polynomials\DglHf\src\polynomials\LaurentPolynomial.jl:493
#   roots(::FactoredPolynomial{T}) where T at C:\Users\Szymon\.julia\packages\Polynomials\DglHf\src\polynomials\factored_polynomial.jl:238
#   roots(::P; kwargs...) where {T, P<:(Polynomials.StandardBasisPolynomial{T})} at C:\Users\Szymon\.julia\packages\Polynomials\DglHf\src\polynomials\standard-basis.jl:440
#   ...
#
# Stacktrace:
#  [1] top-level scope
#    @ In[62]:5
#  [2] eval
#    @ .\boot.jl:373 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base .\loading.jl:1196

# %%
#zadanie 2
